# %% [markdown]
# <h1>WordCloud</h1>

# %%
# Nuvem de tags, nuvem de palavras ou nuvem de etiquetas
# uma lista hierarquizada visualmente, uma forma de apresentar os itens de conteúdo de um website

# %%
# !pip install wordcloud -q

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt


file = r'...\arquivo.xls' # endereço de onde esta o arquivo xlsx ou csv
txt = pd.read_excel(file)
clould = str(txt)

wordcloud = WordCloud(background_color="black", width=1600, height=800).generate(clould)
plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis("off")
wordcloud.to_file(r" ...\nome_imagem.png") # endereço para salvar a imagem
plt.show()
